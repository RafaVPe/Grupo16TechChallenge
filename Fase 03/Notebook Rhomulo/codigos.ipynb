# %% [markdown]
# Parte A - Características gerais dos moradores
# A005
# Escolaridade
#     1	Sem instrução
# 	2	Fundamental incompleto
# 	3	Fundamental completa
# 	4	Médio incompleto
# 	5	Médio completo
# 	6	Superior incompleto
# 	7	Superior completo
# 	8	Pós-graduação, mestrado ou doutorado
# Parte B - COVID19 - Todos os moradores - sintomas
# B0011
# Na semana passada teve febre?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0012
# Na semana passada teve tosse?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0013
# Na semana passada teve dor de garganta?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0014
# Na semana passada teve dificuldade para respirar?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0015
# Na semana passada teve dor de cabeça?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0016
# Na semana passada teve dor no peito?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# - PROVIDENCIAS E CUIDADOS
# B0017
# Na semana passada teve náusea?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0018
# Na semana passada teve nariz entupido ou escorrendo?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B0019
# Na semana passada teve fadiga?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B00110
# Na semana passada teve dor nos olhos?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B00111
# Na semana passada teve perda de cheiro ou sabor?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B00112
# Na semana passada teve dor muscular?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B00113
# Na semana passada teve diarreia?	1	Sim
# 	2	Não
# 	3	Não sabe
# 	9	Ignorado
# B002
# Por causa disso, foi a algum estabelecimento de saúde?	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0031
# Providência tomada para recuperar dos sintomas foi ficar em casa	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0041
# Local que buscou atendimento foi posto de saúde/Unidade básica de saúde /Equipe de Saúde da Família (médico, enfermeiro, técnico de enfermagem ou agente comunitário de saúde)	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0042
# Local que buscou atendimento foi pronto socorro do SUS/UPA	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0043
# Local que buscou atendimento foi hospital do SUS	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0044
# Local que buscou atendimento foi ambulatório ou consultório privado ou ligado às forças armadas	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0045
# Local que buscou atendimento foi pronto socorro privado ou ligado às forças armadas	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B0046
# Local que buscou atendimento foi hospital privado ou ligado às forças armadas	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B005
# Ao procurar o hospital, teve que ficar internado por um dia ou mais	1	Sim
# 	2	Não
# 	3	Não foi atendido
# 	9	Ignorado
# 		Não aplicável
# B006
# Durante a internação, foi sedado, entubado e colocado em respiração artificial com ventilador	1	Sim
# 	2	Não
# 	9	Ignorado
# 		Não aplicável
# B008
# O(A) Sr(a) fez algum teste para saber se estava infectado(a) pelo coronavírus? 	1	Sim
# 	2	Não
# 	9	Ignorado
# B0101
# Algum médico já lhe deu o diagnóstico de diabetes?	1	Sim
# 	2	Não
# 	9	Ignorado
# B0102
# Algum médico já lhe deu o diagnóstico de hipertensão?	1	Sim
# 	2	Não
# 	9	Ignorado
# B0103
# Algum médico já lhe deu o diagnóstico de asma/bronquite/enfisema/doenças respiratória crônica ou doença de pulmão?	1	Sim
# 	2	Não
# 	9	Ignorado
# B0104
# Algum médico já lhe deu o diagnóstico de doenças do coração (infarto, angina, insuficiência cardíaca, arritmia)?	1	Sim
# 	2	Não
# 	9	Ignorado
# B0105
# Algum médico já lhe deu o diagnóstico de depressão?	1	Sim
# 	2	Não
# 	9	Ignorado
# B0106
# Algum médico já lhe deu o diagnóstico de câncer?	1	Sim
# 	2	Não
# 	9	Ignorado
# B011
# Qual foi o resultado do teste?  Na semana passada, devido à pandemia do Coronavírus, em que medida o(a) Sr(a) restringiu o contato com as pessoas? 	1	Não fez restrição, levou vida normal como antes da pandemia
# 	2	Reduziu o contato com as pessoas, mas continuou saindo de casa para trabalho ou atividades não essenciais e/ou recebendo visitas
# 	3	Ficou em casa e só saiu em caso de necessidade básica
# 	4	Ficou rigorosamente em casa
# 	9	Ignorado
# Parte C - Características de trabalho das pessoas de 14 anos ou mais de idade
# C001
# Na semana passada, por pelo menos uma hora, trabalhou ou fez algum bico?
#     1	Sim
# 	2	Não
# 		Não aplicável
# C01012 - Quanto recebia (ou retirava) normalmente em todos os seus trabalhos
# Valor em dinheiro	valor em reais
#         R$
# 		Não aplicável
# C01022 - Quanto recebia (ou retirava) normalmente em todos os seus trabalhos
# Valor em produtos e mercadorias	valor em reais
#         R$
# 		Não aplicável
# C011A12 - Quanto recebia (ou retirava) efetivamente em todos os seus trabalhos
# Valor em dinheiro	valor em reais
#         R$
# 		Não aplicável
# C011A22 - Quanto recebia (ou retirava) efetivamente em todos os seus trabalhos
# Valor em produtos e mercadorias	valor em reais
#         R$
# 		Não aplicável
# C012
# Na maior parte do tempo, na semana passada, esse trabalho (único ou principal) foi exercido no mesmo local em que costuma trabalhar? 	1	Sim
# 	2	Não
# 		Não aplicável
# C013
# Na semana passada, o(a) Sr(a) estava em trabalho remoto (home office ou teletrabalho)?	1	Sim
# 	2	Não
# 		Não aplicável
# Parte D - Rendimento de outras fontes dos moradores de 14 anos ou mais de idade
# D0013 - Rendimento recebido de aposentadoria e pensão por todos os moradores
# Somatório dos valores recebidos
#         valor em reais
# 		Não aplicável
# D0023 - Rendimento de pensão alimentícia, doação ou mesada em dinheiro de pessoa que não morava no domicílio
# Somatório dos valores recebidos
#         valor em reais
# 		Não aplicável
# D0033 - Somatório dos valores recebidos - bolsa família
# Somatório dos valores recebidos - bolsa família
#         valor em reais
# 		Não aplicável
# D0043 -  No mês de ... (mês de referência), ... recebeu rendimentos de Benefício Assistencial de Prestação Continuada – BPC-LOAS?
# Somatório dos valores recebidos
#         valor em reais
# 		Não aplicável
# D0053 - Auxílios emergenciais relacionados ao coronavirus
# Somatório dos valores recebidos
#         valor em reais
# 		Não aplicável
# D0063 - Seguro desemprego
# Somatório dos valores recebidos
#         valor em reais
# 		Não aplicável
# E001
# Durante o período da pandemia alguém deste domicílio solicitou algum empréstimo?  	1	Sim, e pelo menos um morador conseguiu
# 	2	Sim, mas nenhum morador conseguiu
# 	3	Não solicitou
# F001
# Este domicílio é: 	1	Próprio - já pago
# 	2	Próprio - ainda pagando
# 	3	Alugado
# 	4	Cedido por empregador
# 	5	Cedido por familiar
# 	6	Cedido de outra forma
# 	7	Outra condição
# F0021
# Qual foi o valor mensal do aluguel pago, ou que deveria ter sido pago, no mês de referência?	valor em reais	R$
# 		Não aplicável
# F002A1
# No seu domicílio há os seguintes itens básicos de limpeza e proteção: sabão ou detergente	1	Sim
# 	2	Não
# 	3	Não sabe
# F002A2
# No seu domicílio há os seguintes itens básicos de limpeza e proteção: álcool 70% ou superior (gel ou líquido)	1	Sim
# 	2	Não
# 	3	Não sabe
# F002A3
# No seu domicílio há os seguintes itens básicos de limpeza e proteção: máscaras	1	Sim
# 	2	Não
# 	3	Não sabe
# F002A4
# No seu domicílio há os seguintes itens básicos de limpeza e proteção: luvas descartáveis	1	Sim
# 	2	Não
# 	3	Não sabe
# F002A5
# No seu domicílio há os seguintes itens básicos de limpeza e proteção: água sanitária ou desinfetante	1	Sim
# 	2	Não
# 	3	Não sabe
